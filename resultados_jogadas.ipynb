# %%
import pandas as pd


df = pd.read_csv("Magic resultscsv.csv", sep=";",encoding="ISO-8859-1")

vitorias =   df[df["RESULTADO"] == True]

vitorias
# Out:
#     PARTIDA JOGADOR                                 DECK JOGADOR UTILZ  \
# 0       1.0  RAFAEL  Deck\n1 Cavernas de Koilos (DMU) 244\n4 Baixad...
# 1       2.0    LUIZ  Deck\n1 Favor de Etali (LCI) 149\n10 Planície ...
# 2       3.0    LUIZ  Deck\n1 Favor de Etali (LCI) 149\n10 Planície ...
# 3       4.0    LUIZ  Deck\n1 Favor de Etali (LCI) 149\n10 Planície ...
# 6       7.0  RAFAEL  Deck\n1 Cavernas de Koilos (DMU) 244\n4 Baixad...
# 7       8.0  RAFAEL  Deck\n1 Cavernas de Koilos (DMU) 244\n4 Baixad...
# 9      10.0  RAFAEL  Deck\n1 Cavernas de Koilos (DMU) 244\n4 Baixad...
# 12     11.0    LUIZ  Deck\n1 Favor de Etali (LCI) 149\n10 Planície ...
# 13     12.0    LUIZ  Deck\n1 Favor de Etali (LCI) 149\n10 Planície ...
# 16     15.0    LUIZ  Deck\n1 Favor de Etali (LCI) 149\n10 Planície ...
# 19     20.0    LUIZ  Deck\n1 Favor de Etali (LCI) 149\n10 Planície ...
# 20     21.0    LUIZ  Deck\n1 Favor de Etali (LCI) 149\n10 Planície ...
#
# ...
